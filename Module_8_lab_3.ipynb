# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-09 12:31:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   148MB/s    in 0.5s
#
# 2023-05-09 12:31:29 (148 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19384   1304.5970v1  The FOCUS constraint expresses the notion that...    cs
# 34662  1708.02912v1  Since a tweet is limited to 140 characters, it...    cs
# 2147   1607.08316v2  Automatically searching for optimal hyperparam...    cs
# 10166  1710.00892v1  Using a recently proposed privacy definition o...    cs
# 28033  1705.04300v3  Monocular visual odometry (VO) has seen tremen...    cs
# ...             ...                                                ...   ...
# 29283  1708.09839v1  Cameras are a crucial exteroceptive sensor for...    cs
# 16614  1704.05571v1  Word embeddings have made enormous inroads in ...    cs
# 36364   1212.6216v2  Dribbling an opponent player in digital soccer...    cs
# 29545  1709.07212v2  Unsupervised image segmentation and denoising ...    cs
# 7248   1711.04755v1  Generative Adversarial Networks (GANs) are a p...  stat
#
#                                                    title  year  \
# 19384      Three Generalizations of the FOCUS Constraint  2013
# 34662  KeyXtract Twitter Model - An Essential Keyword...  2017
# 2147   Efficient Hyperparameter Optimization of Deep ...  2016
# 10166  Rényi Differential Privacy Mechanisms for Post...  2017
# 28033  Challenges in Monocular Visual Odometry: Photo...  2017
# ...                                                  ...   ...
# 29283  3D Visual Perception for Self-Driving Cars usi...  2017
# 16614  Predicting Role Relevance with Minimal Domain ...  2017
# 36364  Generating Motion Patterns Using Evolutionary ...  2012
# 29545  A First Derivative Potts Model for Segmentatio...  2017
# 7248     ACtuAL: Actor-Critic Under Adversarial Learning  2017
#
#                                                 keywords
# 19384  [constraint, expresses, solutions, concentrate...
# 34662  [characters, ambiguous, difficult, traditional...
# 2147   [automatically, searching, hyperparameter, con...
# 10166  [definition, differential, releasing, posterio...
# 28033  [monocular, tremendous, improvements, robustne...
# ...                                                  ...
# 29283  [exteroceptive, appearance, information, envir...
# 16614  [embeddings, applications, embedding, architec...
# 36364  [dribbling, environment, important, practical,...
# 29545  [unsupervised, segmentation, denoising, fundam...
# 7248   [generative, adversarial, framework, generativ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19384    [constraint, expresses, solutions, concentrate...
# 34662    [characters, ambiguous, difficult, traditional...
# 2147     [automatically, searching, hyperparameter, con...
# 10166    [definition, differential, releasing, posterio...
# 28033    [monocular, tremendous, improvements, robustne...
#                                ...
# 8377     [interpret, euclidean, functional, discretely,...
# 39815    [automated, character, extraction, motivated, ...
# 8060     [generalization, technique, generalization, di...
# 3969     [artificial, successfully, recommender, databa...
# 19512    [inferences, particularly, determine, framewor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8801 words.
# Out of those 4526 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4624e21f-d435-434b-aca0-95bae9543c5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4624e21f-d435-434b-aca0-95bae9543c5a")) {                    Plotly.newPlot(                        "4624e21f-d435-434b-aca0-95bae9543c5a",                        [{"x":["semantics","constraint","algorithm","expresses","concentrated","filtering","decompositions","discussing","solutions","generalizations","increased","evaluated","recognition","extraction","essential","analysing","consisted","lemmatization","developed","processing","addressing","shortcomings","linguistic","difficult","extracted","ambiguous","development","performance","characters","telecommunication","traditional","statistics","efficient","optimizing","promising","demonstrate","automatically","deterministic","obtaining","hyperparameter","optimization","dimensions","significantly","extensive","inefficient","evaluations","configurations","processes","exceptionally","distribution","probabilistic","importance","approximate","surrogates","coordinate","configuration","searching","validation","estimates","established","expensive","functions","sufficient","algorithms","surrogate","outperforms","hyperparameters","regression","generalized","achieving","framework","arbitrary","differential","definition","releasing","influence","experimental","individual","guarantees","exponential","particular","mechanisms","posterior","mitigating","photometric","conclusions","popularity","performed","providing","technical","community","practical","calibration","insightful","improvements","influences","overlooked","refinement","quantitatively","monocular","efficiency","knowledge","influential","tremendous","nevertheless","robustness","experiments","challenges","empirical","comprehensive","developing","exhaustively","efficiently","neighborhoods","statistical","underlying","structure","information","temperatures","communities","computation","necessary","computational","independent","assumptions","identifiability","structural","procedure","significant","reconstructing","restricted","parameters","guaranteed","approaches","mitigates","conditions","benchmark","introduced","logarithmic","sequentially","complexity","incremental","differentiable","description","according","introduce","partitions","sequential","elegantly","increases","gradually","asymptotically","particularly","regressor","convergence","regularity","predicting","conventional","piecewise","nonlinear","hierarchical","beginning","experiment","minimally","exploiting","exploration","validated","recovering","augmented","reconstruction","typically","tomography","applications","correlation","alternative","stochastic","variational","divergences","objective","optimizes","reparametrization","correlated","uncorrelated","divergence","estimating","rightarrow","inference","estimator","investigate","parameter","important","effectively","aggregating","synthetic","attributes","preference","improvement","corrupted","techniques","inconsistent"],"y":[100,92,814,5,6,73,10,2,136,8,45,147,377,126,64,7,4,2,213,288,29,13,81,162,113,12,125,926,30,2,178,70,405,48,122,545,177,42,32,13,323,47,253,140,25,43,34,105,3,220,160,81,122,2,26,26,25,47,77,46,54,244,76,633,10,249,16,122,77,76,552,101,30,52,3,63,416,120,65,66,280,53,41,11,10,8,25,108,96,38,83,146,20,5,128,17,3,18,30,24,157,357,8,17,23,92,606,112,148,60,66,2,145,10,155,123,348,688,2,19,127,77,274,128,75,8,79,124,244,12,55,264,36,435,3,143,194,117,16,21,228,32,22,71,108,309,23,76,4,50,10,14,70,8,107,10,91,100,18,58,90,6,78,7,86,52,38,26,47,94,107,21,453,70,98,135,65,6,143,11,0,30,0,29,65,2,230,25,150,120,363,120,20,137,50,18,160,20,348,17],"type":"bar"},{"x":["semantics","constraint","algorithm","expresses","concentrated","filtering ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4526,), (4526, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7916666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>Sparsity</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constrained</span> <span style=''>Block</span> <span style='background-color:rgba(255, 0, 0, 0.5652173913043479);'>Subsampling</span> <span style=''>for</span> <span style=''>Improved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sensitivity</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.48201438848920863);'>Discriminative</span> <span style=''>Voxel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Identification</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>voxel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3035714285714286);'>functional</span> <span style=''>Magnetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Resonance</span> <span style=''>Imaging</span> <span style=''>(fMRI)</span> <span style=''>brain</span> <span style=''>data</span> <span style=''>with</span> <span style=''>the</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>more</span> <span style=''>complete</span> <span style=''>set</span> <span style=''>of</span> <span style=''>probably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style='background-color:rgba(0, 255, 0, 0.48201438848920863);'>discriminative</span> <span style=''>voxels</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3132530120481928);'>improving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>biomarkers</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.34246575342465746);'>difficulty</span> <span style=''>in</span> <span style=''>doing</span> <span style=''>this</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3392539964476022);'>dimensional</span> <span style=''>voxel</span> <span style=''>space</span> <span style=''>and</span> <span style=''>few</span> <span style=''>training</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>unreliable</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.34246575342465746);'>difficulty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>has</span> <span style=''>received</span> <span style=''>a</span> <span style=''>great</span> <span style=''>deal</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.40625000000000006);'>attention</span> <span style=''>lately</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>finite</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinearly</span> <span style=''>with</span> <span style=''>its</span> <span style=''>clusters</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>acceleration</span> <span style=''>of</span> <span style=''>GMMs</span> <span style=''>and</span> <span style=''>k</span> <span style=''>means</span> <br/><br/><span style=''>One</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>of</span> <span style=''>k</span> <span style=''>means</span> <span style=''>or</span> <span style=''>EM</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>(GMMs)</span> <span style=''>scales</span> <span style=''>linearly</span> <span style=''>with</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>N</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>C</span> <span style=''>and</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>D</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>whether</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>of</span> <span style=''>k</span> <span style=''>means</span> <span style=''>or</span> <span style=''>EM</span> <span style=''>for</span> <span style=''>GMMs</span> <span style=''>can</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinearly</span> <span style=''>with</span> <span style=''>C</span> <span style=''>at</span> <span style=''>run</span> <span style=''>time</span> <span style=''>while</span> <span style=''>the</span> <span style=''>increase</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>remains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>The</span> <span style=''>tool</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>EM</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>make</span> <span style=''>training</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style=''>many</span> <span style=''>hidden</span> <span style=''>states</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>results</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>wise</span> <span style=''>leading</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenvector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <br/><br/><span style=''>We</span> <span style=''>develop</span> <span style=''>and</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>wise</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>leading</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenvector</span> <span style=''>where</span> <span style=''>each</span> <span style=''>step</span> <span style=''>involves</span> <span style=''>only</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>vector</span> <span style=''>product</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.416058394160584);'>establish</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3920454545454547);'>convergence</span> <span style=''>with</span> <span style=''>overall</span> <span style=''>runtime</span> <span style='background-color:rgba(255, 0, 0, 0.3564356435643564);'>guarantees</span> <span style=''>that</span> <span style=''>are</span> <span style=''>at</span> <span style=''>least</span> <span style=''>as</span> <span style=''>good</span> <span style=''>as</span> <span style=''>Lanczoss</span> <span style=''>method</span> <span style=''>and</span> <span style=''>dominate</span> <span style=''>it</span> <span style=''>for</span> <span style=''>slowly</span> <span style=''>decaying</span> <span style=''>spectrum</span> <span style=''>Our</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combining</span> <span style=''>a</span> <span style=''>shift</span> <span style=''>and</span> <span style=''>invert</span> <span style=''>approach</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.4884696016771488);'>regression</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style=''>Random</span> <span style=''>Forests</span> <span style=''>From</span> <span style=''>Theory</span> <span style=''>to</span> <span style=''>Practice</span> <br/><br/><span style=''>Data</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>have</span> <span style=''>become</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrative</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style=''>modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>offering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>based</span> <span style=''>on</span> <span style=''>past</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>unraveling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>insights</span> <span style=''>about</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>Yet</span> <span style=''>caution</span> <span style=''>should</span> <span style=''>avoid</span> <span style=''>using</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>as</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style=''>tool</span> <span style=''>but</span> <span style=''>rather</span> <span style=''>consider</span> <span style=''>it</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>with</span> <span style=''>a</span> <span style=''>rational</span> <span style=''>thought</span> <span style=''>process</span> <span style=''>that</span> <span style=''>is</span> <span style=''>entirely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>on</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>study</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>should</span> <span style=''>ideally</span> <span style=''>require</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>better</span> <span style=''>apprehend</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>their</span> <span style=''>results</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Accordingly</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>of</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10311493018259936)
# 	architecture (0.08628714643752237)
# 	knowledge (0.12781954887218044)
# 	representation (0.13068385248836376)
# 	information (0.24633011099176513)
# 	detection (0.11457214464733262)
# 	experimental (0.1489437880415324)
# 	different (0.2774794128177587)
# 	convolutional (0.13462226996061583)
# 	recognition (0.13498030791263874)
#
# Some Statistics words are:
# 	theoretical (0.15495764823119082)
# 	stochastic (0.14050822122571002)
# 	algorithm (0.38714499252615847)
# 	distribution (0.17488789237668162)
# 	variables (0.14798206278026907)
# 	statistical (0.15495764823119082)
# 	estimation (0.16791230692575984)
# 	inference (0.19133034379671152)
# 	dimensional (0.1878425510712506)
# 	regression (0.1768809167912307)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="207d8108-ab80-469b-9d01-462072639d4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("207d8108-ab80-469b-9d01-462072639d4b")) {                    Plotly.newPlot(                        "207d8108-ab80-469b-9d01-462072639d4b",                        [{"x":["semantics","constraint","algorithm","expresses","concentrated","filtering","decompositions","discussing","solutions","generalizations","increased","evaluated","recognition","extraction","essential","analysing","consisted","lemmatization","developed","processing","addressing","shortcomings","linguistic","difficult","extracted","ambiguous","development","performance","characters","telecommunication","traditional","statistics","efficient","optimizing","promising","demonstrate","automatically","deterministic","obtaining","hyperparameter","optimization","dimensions","significantly","extensive","inefficient","evaluations","configurations","processes","exceptionally","distribution","probabilistic","importance","approximate","surrogates","coordinate","configuration","searching","validation","estimates","established","expensive","functions","sufficient","algorithms","surrogate","outperforms","hyperparameters","regression","generalized","achieving","framework","arbitrary","differential","definition","releasing","influence","experimental","individual","guarantees","exponential","particular","mechanisms","posterior","mitigating","photometric","conclusions","popularity","performed","providing","technical","community","practical","calibration","insightful","improvements","influences","overlooked","refinement","quantitatively","monocular","efficiency","knowledge","influential","tremendous","nevertheless","robustness","experiments","challenges","empirical","comprehensive","developing","exhaustively","efficiently","neighborhoods","statistical","underlying","structure","information","temperatures","communities","computation","necessary","computational","independent","assumptions","identifiability","structural","procedure","significant","reconstructing","restricted","parameters","guaranteed","approaches","mitigates","conditions","benchmark","introduced","logarithmic","sequentially","complexity","incremental","differentiable","description","according","introduce","partitions","sequential","elegantly","increases","gradually","asymptotically","particularly","regressor","convergence","regularity","predicting","conventional","piecewise","nonlinear","hierarchical","beginning","experiment","minimally","exploiting","exploration","validated","recovering","augmented","reconstruction","typically","tomography","applications","correlation","alternative","stochastic","variational","divergences","objective","optimizes","reparametrization","correlated","uncorrelated","divergence","estimating","rightarrow","inference","estimator","investigate","parameter","important","effectively","aggregating","synthetic","attributes","preference","improvement","corrupted","techniques","inconsistent","furthermore","aggregation","ubiquitous","available","unsupervised","expertise","aggregated","manuscript","challenging","consensus","protocols","sophisticated","discusses","targeting","verification","embedding","discriminative","dimensional","variations","including","diffusion","effectiveness","generation","introduces","segmentation","probability","qualitative","quantitative","satisfactorily","consecutive","interferences","biometric","complexion","homogeneous","illumination","background","unidentified","inefficiency","associated","initially","limitations","equipment","accompanying","addresses","detection","technique","wasserstein","requirements","directions","prominent","corresponding","determining","direction","distributions","guarantee ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reparametrization
# 	uncorrelated
# 	encapsulates
# 	disentanglement
# 	ergodicity
# 	instrumental
# 	substantive
# 	cancellation
# 	blockmodel
# 	blockmodels
# 	logarithmically
# 	sparseness
# 	parameterizes
# 	emphmulti
# 	discounting
# 	equiangular
# 	asymptotics
# 	photovoltaic
# 	spectroradiometer
# 	reflectivity
# Some words which never appear in Statistics papers:
# 	lemmatization
# 	telecommunication
# 	exceptionally
# 	photometric
# 	monocular
# 	exhaustively
# 	interferences
# 	complexion
# 	unidentified
# 	equipment
# 	clarifying
# 	argumentation
# 	unfounded
# 	accelerators
# 	credibility
# 	parameterisation
# 	institute
# 	unrepresentative
# 	interference
# 	temporarily

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0810944047325615e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
